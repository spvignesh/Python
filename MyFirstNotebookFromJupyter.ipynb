# %%
print("Hello World!")
print("Welcome")
# Out:
# Hello World!
# Welcome

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])

# %%
import matplotlib.pyplot as plt
import numpy as nm
plt.plot(nm.arange(5))
